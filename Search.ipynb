# %%
# %load_ext aiida
# %aiida
# Out:
# Loaded AiiDA DB environment - profile name: default.

# %%
from empasiesta_tools.widgets.search_structures_widget import SearchStructuresWidget

search = SearchStructuresWidget()
display(search)
